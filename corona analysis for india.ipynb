# %% [markdown]
# # Covid-19 analysis for India from 30/01/2020 to 08/04/2020

# %% [markdown]
# # Report by SRINIVASH V (181EC267)

# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
datasets=pd.read_csv("C:/Users/PC/Downloads/new/Complete.csv")

# %%
datasets
# Out:
#            Date Name of State / UT  Total Confirmed cases (Indian National)  \
# 0    2020-01-30             Kerala                                        1
# 1    2020-01-31             Kerala                                        1
# 2    2020-02-01             Kerala                                        2
# 3    2020-02-02             Kerala                                        3
# 4    2020-02-03             Kerala                                        3
# ..          ...                ...                                      ...
# 759  2020-04-08          Telengana                                        0
# 760  2020-04-08            Tripura                                        0
# 761  2020-04-08      Uttar Pradesh                                        0
# 762  2020-04-08        Uttarakhand                                        0
# 763  2020-04-08        West Bengal                                        0
#
# ...

# %%
datasets.isnull().sum()
# Out:
# Date                                          0
# Name of State / UT                            0
# Total Confirmed cases (Indian National)       0
# Total Confirmed cases ( Foreign National )    0
# Cured/Discharged/Migrated                     0
# Latitude                                      0
# Longitude                                     0
# Death                                         0
# Total Confirmed cases                         0
# dtype: int64

# %%
datasets.columns
# Out:
# Index(['Date', 'Name of State / UT', 'Total Confirmed cases (Indian National)',
#        'Total Confirmed cases ( Foreign National )',
#        'Cured/Discharged/Migrated', 'Latitude', 'Longitude', 'Death',
#        'Total Confirmed cases'],
#       dtype='object')

# %%
print("Corona affected states in India")
datasets['Name of State / UT'].unique()
# Out:
# Corona affected states in India
# array(['Kerala', 'Delhi', 'Telengana', 'Rajasthan', 'Haryana',
#        'Uttar Pradesh', 'Tamil Nadu', 'Union Territory of Ladakh',
#        'Karnataka', 'Maharashtra', 'Punjab',
#        'Union Territory of Jammu and Kashmir', 'Andhra Pradesh',
#        'Uttarakhand', 'Odisha', 'Puducherry', 'West Bengal',
#        'Chhattisgarh', 'Union Territory of Chandigarh', 'Gujarat',
#        'Chandigarh', 'Himachal Pradesh', 'Jammu and Kashmir', 'Ladakh',
#        'Madhya Pradesh', 'Bihar', 'Manipur', 'Mizoram',
#        'Andaman and Nicobar Islands', 'Goa', 'Assam', 'Jharkhand',
#        'Arunachal Pradesh', 'Tripura'], dtype=object)

# %%
datasets.groupby(['Name of State / UT'])['Total Confirmed cases'].max().sum()
# Out:
# 5209

# %% [markdown]
# # Total number of corona positive cases in India till 08/04/2020 is 5209

# %%
datasets.groupby(['Name of State / UT'])['Cured/Discharged/Migrated'].max().sum()
# Out:
# 403

# %% [markdown]
# # Total number of cured cases in India till 08/04/2020 is 403

# %%
datasets.groupby(['Name of State / UT'])['Death'].max().sum()
# Out:
# 149

# %% [markdown]
# # Total number of Death cases in India till 08/04/2020 is 149

# %%
print("Corona confirmed cases in each states")
datasets.groupby(['Name of State / UT'])['Total Confirmed cases'].max().sort_values()
# Out:
# Corona confirmed cases in each states
# Name of State / UT
# Arunachal Pradesh                          1
# Union Territory of Chandigarh              1
# Tripura                                    1
# Mizoram                                    1
# Manipur                                    2
# Union Territory of Jammu and Kashmir       4
# Jharkhand                                  4
# Puducherry                                 5
# Goa                                        7
# Andaman and Nicobar Islands               10
# Union Territory of Ladakh                 10
# Chhattisgarh                              10
# Ladakh                                    14
# Himachal Pradesh                          18
# Chandigarh                                18
# Assam                                     27
# Uttarakhand                               31
# Bihar                                     38
# Odisha                                    42
# ...

# %% [markdown]
# # Corona positive cases in each states of India

# %%
datasets.groupby(['Name of State / UT'])['Total Confirmed cases'].max().sort_values().plot(kind="bar",figsize=(15,8), color='b', title="Covid-19 Positive cases in India")

# %%
print("corona cured cases in each states")
datasets.groupby(['Name of State / UT'])['Cured/Discharged/Migrated'].max().sort_values()
# Out:
# corona cured cases in each states
# Name of State / UT
# Union Territory of Chandigarh            0
# Manipur                                  0
# Arunachal Pradesh                        0
# Assam                                    0
# Bihar                                    0
# Madhya Pradesh                           0
# Union Territory of Ladakh                0
# Goa                                      0
# Union Territory of Jammu and Kashmir     0
# Mizoram                                  0
# Tripura                                  0
# Jharkhand                                0
# Puducherry                               1
# Andaman and Nicobar Islands              1
# Andhra Pradesh                           1
# Himachal Pradesh                         2
# Odisha                                   2
# Punjab                                   4
# Jammu and Kashmir                        4
# Uttarakhand                              5
# ...

# %% [markdown]
# # Corona Cured cases in each states of India

# %%
datasets.groupby(['Name of State / UT'])['Cured/Discharged/Migrated'].max().sort_values().plot(kind="bar",figsize=(14,8),color='g',title="Recovery Rate of Covid-19 in India")

# %%
print("Corona death cases in each states")
datasets.groupby(['Name of State / UT'])['Death'].max().sort_values()
# Out:
# Corona death cases in each states
# Name of State / UT
# Andaman and Nicobar Islands              0
# Union Territory of Ladakh                0
# Union Territory of Jammu and Kashmir     0
# Union Territory of Chandigarh            0
# Tripura                                  0
# Puducherry                               0
# Mizoram                                  0
# Manipur                                  0
# Uttarakhand                              0
# Jharkhand                                0
# Ladakh                                   0
# Chandigarh                               0
# Arunachal Pradesh                        0
# Assam                                    0
# Goa                                      0
# Chhattisgarh                             0
# Bihar                                    1
# Odisha                                   1
# Himachal Pradesh                         1
# Kerala                                   2
# ...

# %% [markdown]
# # Corona Death cases in each states of India

# %%
datasets.groupby(['Name of State / UT'])['Death'].max().sort_values().plot(kind="bar",figsize=(15,9),title="Death rate of covid-19 in India",color='r')

# %%
print("Corona confirmed cases in each days from 30/01/2020 to 08/04/2020")
datasets.groupby(['Date'])['Total Confirmed cases'].sum()
# Out:
# Corona confirmed cases in each days from 30/01/2020 to 08/04/2020
# Date
# 2020-01-30       1
# 2020-01-31       1
# 2020-02-01       2
# 2020-02-02       3
# 2020-02-03       3
#               ...
# 2020-04-04    2839
# 2020-04-05    3374
# 2020-04-06    4067
# 2020-04-07    4421
# 2020-04-08    5194
# Name: Total Confirmed cases, Length: 70, dtype: int64

# %% [markdown]
# # Growth Rate of Covid-19 Positive Cases in India

# %%
datasets.groupby(['Date'])['Total Confirmed cases'].sum().plot(kind="line",figsize=(15,9),title="Growth Rate of Covid-19 Positive Cases in India")

# %%
print("Corona death cases in each days from 30/01/2020 to 08/04/2020")
datasets.groupby(['Date'])['Death'].sum()
# Out:
# Corona death cases in each days from 30/01/2020 to 08/04/2020
# Date
# 2020-01-30      0
# 2020-01-31      0
# 2020-02-01      0
# 2020-02-02      0
# 2020-02-03      0
#              ...
# 2020-04-04     65
# 2020-04-05     77
# 2020-04-06    109
# 2020-04-07    114
# 2020-04-08    149
# Name: Death, Length: 70, dtype: int64

# %% [markdown]
# # Death Rate of Covid-19 Cases in India

# %%
datasets.groupby(['Date'])['Death'].sum().plot(kind="line",figsize=(15,9),title="Death Rate of Covid-19 Cases in India",color='r')

# %%
print("Corona cured cases in each days from 30/01/2020 to 08/04/2020")
datasets.groupby(['Date'])['Cured/Discharged/Migrated'].sum()
# Out:
# Corona cured cases in each days from 30/01/2020 to 08/04/2020
# Date
# 2020-01-30      0
# 2020-01-31      0
# 2020-02-01      0
# 2020-02-02      0
# 2020-02-03      0
#              ...
# 2020-04-04    181
# 2020-04-05    267
# 2020-04-06    292
# 2020-04-07    326
# 2020-04-08    402
# Name: Cured/Discharged/Migrated, Length: 70, dtype: int64

# %% [markdown]
# # Recovery Rate of Covid-19 Cases in India

# %%
datasets.groupby(['Date'])['Cured/Discharged/Migrated'].sum().plot(kind="line",figsize=(15,9),title="Recovery Rate of Covid-19 Cases in India",color='g')

# %%
style.use('ggplot')
plt.figure(figsize=(20,9))
plt.plot(datasets.groupby(['Date'])['Total Confirmed cases'].sum(),'b', label="Corona positive cases", linewidth=4)
plt.plot(datasets.groupby(['Date'])['Death'].sum(),'r', label="corona death cases", linewidth=5)
plt.plot(datasets.groupby(['Date'])['Cured/Discharged/Migrated'].sum(),'g', label="corona cured cases", linewidth=6)
plt.title("Covid-19 cases in India")
plt.legend()
plt.show()

# %% [markdown]
# ### From the above graph, the number of corona positive cases in India is increasing in a drastic manner. There is no evidence of decreasing in the disease spread. On the other hand recovery rate also increasing slightly.

# %%
tamilnadu=datasets.loc[datasets['Name of State / UT']=='Tamil Nadu']
tamilnadu.head()
# Out:
#            Date Name of State / UT  Total Confirmed cases (Indian National)  \
# 61   2020-03-07         Tamil Nadu                                        1
# 69   2020-03-08         Tamil Nadu                                        1
# 80   2020-03-09         Tamil Nadu                                        1
# 92   2020-03-10         Tamil Nadu                                        1
# 104  2020-03-11         Tamil Nadu                                        1
#
#      Total Confirmed cases ( Foreign National )  Cured/Discharged/Migrated  \
# 61                                            0                          0
# 69                                            0                          0
# 80                                            0                          0
# 92                                            0                          0
# 104                                           0                          0
#
#      Latitude  Longitude  Death  Total Confirmed cases
# ...

# %% [markdown]
# # Corona update in Tamil Nadu till 08/04/2020

# %%
style.use('ggplot')
plt.figure(figsize=(15,9))
plt.plot(tamilnadu.groupby(['Date'])['Total Confirmed cases'].sum(),'b', label="Corona positive cases", linewidth=4)
plt.plot(tamilnadu.groupby(['Date'])['Death'].sum(),'r', label="corona death cases", linewidth=5)
plt.plot(tamilnadu.groupby(['Date'])['Cured/Discharged/Migrated'].sum(),'g', label="corona cured cases", linewidth=6)
plt.title("Covid-19 cases in Tamilnadu")
plt.legend()
plt.show()

# %% [markdown]
# ### Hence, the number of corona positive cases in Tamil Nadu are increasing raplidly. Death rate and recovery rate have very less difference, but recovery rate of corona may increase in future compared to death rate.
